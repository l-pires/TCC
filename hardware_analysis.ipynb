# %%
import matplotlib.pyplot as plt

# %%
dist = [15, 14, 13, 12, 11, 10, 9, 8, 7, 6, 5, 4]
smartphone = [890, 881, 868, 852, 828, 801, 762, 717, 641, 522, 316, 174]
tablet = [941, 939, 935, 931, 925, 917, 906, 892, 866, 833, 786, 703]
espelho = [817, 801, 777, 759, 715, 660, 608, 530, 421, 295, 149, 122]

# %%
plt.plot(dist, smartphone, '-o', label='Smartphone')
plt.plot(dist, tablet, '-o', label='Tablet')
plt.plot(dist, espelho, '-o', label='Caso ideal')

plt.xlabel('Distância (cm)')
plt.ylabel('Leitura do receptor')
plt.legend()
plt.show()

# %%
dist = [15, 14, 13, 12, 11, 10, 9, 8, 7, 6, 5, 4]
smartphone = [744, 721, 695, 665, 628, 582, 530, 474, 402, 324, 378, 548]
tablet = [878, 869, 860, 846, 841, 826, 816, 802, 790, 758, 777, 825]
espelho = [446, 420, 293, 228, 211, 202, 171, 162, 150, 142, 141, 143]

# %%
plt.plot(dist, smartphone, '-o', label='Smartphone')
plt.plot(dist, tablet, '-o', label='Tablet')
plt.plot(dist, espelho, '-o', label='Caso ideal')

plt.xlabel('Distância (cm)')
plt.ylabel('Leitura do receptor')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 plt.plot(dist, smartphone, '-o', label='Smartphone')
#       2 plt.plot(dist, tablet, '-o', label='Tablet')
#       3 plt.plot(dist, espelho, '-o', label='Caso ideal')
#
# File ~/.local/share/virtualenvs/code-wYw-Oczj/lib/python3.8/site-packages/matplotlib/pyplot.py:2748, in plot(scalex, scaley, data, *args, **kwargs)
#    2746 @_copy_docstring_and_deprecators(Axes.plot)
#    2747 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2748     return gca().plot(
#    2749         *args, scalex=scalex, scaley=scaley,
#    2750         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/.local/share/virtualenvs/code-wYw-Oczj/lib/python3.8/site-packages/matplotlib/axes/_axes.py:1668, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1425 """
#    1426 Plot y versus x as lines and/or markers.
#    1427
#    (...)
#    1665 (``'green'``) or hex strings (``'#008000'``).
#    1666 """
#    1667 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1668 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1669 for line in lines:
#    1670     self.add_line(line)
#
# File ~/.local/share/virtualenvs/code-wYw-Oczj/lib/python3.8/site-packages/matplotlib/axes/_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
#     312     this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey)
#
# File ~/.local/share/virtualenvs/code-wYw-Oczj/lib/python3.8/site-packages/matplotlib/axes/_base.py:504, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     501     self.axes.yaxis.update_units(y)
#     503 if x.shape[0] != y.shape[0]:
# --> 504     raise ValueError(f"x and y must have same first dimension, but "
#     505                      f"have shapes {x.shape} and {y.shape}")
#     506 if x.ndim > 2 or y.ndim > 2:
#     507     raise ValueError(f"x and y can be no greater than 2D, but have "
#     508                      f"shapes {x.shape} and {y.shape}")
#
# ValueError: x and y must have same first dimension, but have shapes (12,) and (3,)

# %%
angulo = [0, 10, 20]
smartphone = [780, 835, 930]
tablet = [898, 916, 942]
espelho = [642, 766, 931]

# %%
plt.plot(angulo, smartphone, '-o', label='Smartphone')
plt.plot(angulo, tablet, '-o', label='Tablet')
plt.plot(angulo, espelho, '-o', label='Caso ideal')

plt.xlabel('Ângulo (°)')
plt.ylabel('Leitura do receptor')
plt.legend()
plt.show()

# %%
angulo = [0, 10, 20]
smartphone = [584, 624, 704]
tablet = [824, 827, 855]
espelho = [201, 203, 619]

# %%
plt.plot(angulo, smartphone, '-o', label='Smartphone')
plt.plot(angulo, tablet, '-o', label='Tablet')
plt.plot(angulo, espelho, '-o', label='Caso ideal')

plt.xlabel('Ângulo (°)')
plt.ylabel('Leitura do receptor')
plt.legend()
plt.show()
